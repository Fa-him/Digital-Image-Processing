# %% [markdown]
# Task-01: Take a 6x6 NumPy array apply convolution operation of the array. Use zero padding and consider a 3x3 mask/kernel for convolution (with and without built in function). Show both input and output array. Show both input and output NumPy array into an image and show them a subplot with a title.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

arr=np.random.randint(0,255,(6,6), dtype=np.uint8)
temp=arr.copy()
arr=np.pad(arr,1,'constant', constant_values=0)

filter=np.array([
    [1,2,1],
    [2,4,2],
    [1,2,1]
]) /16

ans=arr.copy()

for i in range(1,arr.shape[0]-1):
  for j in range(1,arr.shape[1]-1):
    ans[i,j]=round(np.sum(arr[i-1:i+2, j-1:j+2] * filter))

ans=ans[1:ans.shape[0]-1, 1:ans.shape[1]-1]
print("Manual Convolution Result: \n",ans)
conv2=cv2.filter2D(arr,-1,filter)
conv2=conv2[1:conv2.shape[0]-1, 1:conv2.shape[1]-1]
print("Built in Convolution Result: \n", conv2)
print("\n")

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(temp,cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(ans,cmap='gray')
plt.title("After Manual Convolution")

plt.subplot(1,3,3)
plt.imshow(conv2, cmap="gray")
plt.title("After Built-in Convolution")

plt.show()
# Out:
# Manual Convolution Result:
#  [[ 90 108 109  82  66  71]
#  [120 132 108  83  99 114]
#  [118 122 104  86 100 115]
#  [121 146 142 122 110  88]
#  [132 172 153 135 131  79]
#  [ 92 120 111 105 113  74]]
# Built in Convolution Result:
#  [[ 90 108 109  82  66  71]
#  [120 132 108  83  99 114]
#  [118 122 104  86 100 115]
#  [121 146 142 122 110  88]
#  [132 172 153 135 131  79]
#  [ 92 120 111 105 113  74]]

# %% [markdown]
# Task-02: Take an 8bit grayscale image and apply smoothing operation by using mean filter (with and without built in image smoothing function). Show both input image side by side in a subplot with a title.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")
img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

filter=np.ones((3,3))/9

ans=img_gray.copy()

ans=np.pad(ans,1,'constant', constant_values=0)

for i in range(1, ans.shape[0]-1):
  for j in range(1, ans.shape[1]-1):
    ans[i,j]=round(np.sum(ans[i-1:i+2, j-1:j+2]*filter))

ans=ans[1:ans.shape[0]-1, 1:ans.shape[1]-1]

conv2=cv2.filter2D(img_gray, -1, filter)

plt.figure(figsize=(10,10))

plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(ans, cmap='gray')
plt.title('Mean filter (manual)')

plt.subplot(1,3,3)
plt.imshow(conv2,cmap='gray')
plt.title('Mean filter (Built-in)')

plt.show()

# %% [markdown]
# Task-03: Take an 8bit grayscale image and apply smoothing operation by using weighted averaging filter(with and without built in image smoothing function). Show both input and output image side by side in a subplot with a title.

# %%
import cv2
import numpy as np
import matplotlib.pyplot

img=cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")

img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

filter=np.array([
    [1,2,1],
    [2,4,2],
    [1,2,1]
]) /16

ans=img_gray.copy()

ans=np.pad(ans,1, 'constant', constant_values=0)

for i in range(1, ans.shape[0]-1):
  for j in range(1, ans.shape[1]-1):
    ans[i,j]=round(np.sum(ans[i-1:i+2, j-1:j+2] * filter))

ans=ans[1:ans.shape[0]-1, 1:ans.shape[1]-1]

conv2=cv2.filter2D(img_gray, -1, filter)

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title("Original image")

plt.subplot(1,3,2)
plt.imshow(ans, cmap='gray')
plt.title("Weighted Average(Manual)")

plt.subplot(1,3,3)
plt.imshow(conv2, cmap='gray')
plt.title('Weighted average(built-in)')

plt.show()

# %% [markdown]
# Task-04: Take an 8bit grayscale image and apply smoothing operation by using gaussian filter(with and without built in image smoothing function). Show both input and output image side by side in a subplot with a title.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")
img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

filter=np.array([
    [1,2,1],
    [2,4,2],
    [1,2,1]
]) /16

ans=np.pad(img_gray.copy(),1,'constant', constant_values=0)

for i in range(1, ans.shape[0]-1):
  for j in range(1, ans.shape[1]-1):
    ans[i,j]=round(np.sum(ans[i-1:i+2, j-1:j+2]*filter))

ans=ans[1:ans.shape[0]-1, 1:ans.shape[1]-1]

conv2=cv2.filter2D(img_gray,-1, filter)

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(ans, cmap='gray')
plt.title('Minimum Filter(manual)')

plt.subplot(1,3,3)
plt.imshow(conv2,cmap='gray')
plt.title('Gaussian Filter(Built-in)')

plt.show()

# %% [markdown]
# Task-05: minimum

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")
img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


ans=np.pad(img_gray.copy(),1,'constant', constant_values=0)

for i in range(1, ans.shape[0]-1):
  for j in range(1, ans.shape[1]-1):
    ans[i,j]=round(np.min(ans[i-1:i+2, j-1:j+2]))

ans=ans[1:ans.shape[0]-1, 1:ans.shape[1]-1]


filter=np.ones((3,3), dtype=np.uint8)
conv2=cv2.erode(img_gray, filter)

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')

plt.subplot(1,3,2)
plt.imshow(ans, cmap='gray')
plt.title('Minimum Filter(manual)')

plt.subplot(1,3,3)
plt.imshow(conv2,cmap='gray')
plt.title('Minimum Filter(Built-in)')

plt.show()

# %% [markdown]
# Task-06: Max

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

src = np.pad(img_gray, 1, 'constant', constant_values=0)
ans = src.copy()

out = ans.copy()
for i in range(1, ans.shape[0]-1):
    for j in range(1, ans.shape[1]-1):
        out[i, j] = np.max(src[i-1:i+2, j-1:j+2])

ans = out[1:out.shape[0]-1, 1:out.shape[1]-1]

kernel = np.ones((3,3), dtype=np.uint8)
conv2 = cv2.dilate(img_gray, kernel)

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(ans, cmap='gray')
plt.title('Maximum Filter (manual)')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(conv2, cmap='gray')
plt.title('Maximum Filter (Built-in)')
plt.axis('off')

plt.show()

# %% [markdown]
# Task-07: Sharpening (Laplacian)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/content/drive/MyDrive/cse 3216/gray_img.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

kernel = np.array([[0,1,0],[1,-4,1],[0,1,0]], dtype=np.int32)

work = img_gray.astype(np.int32)
padded = np.pad(work, 1, mode='constant', constant_values=0)
out_manual = np.zeros_like(work, dtype=np.int32)

for i in range(1, padded.shape[0]-1):
    for j in range(1, padded.shape[1]-1):
        out_manual[i-1, j-1] = int(np.sum(padded[i-1:i+2, j-1:j+2] * kernel))

out_manual_disp = np.clip(np.abs(out_manual), 0, 255).astype(np.uint8)

conv2_16s = cv2.filter2D(img_gray, cv2.CV_16S, kernel)
conv2 = cv2.convertScaleAbs(conv2_16s)

plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(out_manual_disp, cmap='gray')
plt.title('Laplacian (manual)')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(conv2, cmap='gray')
plt.title('Laplacian (cv2)')
plt.axis('off')

plt.show()
